# %%
# !pip install langchain langchain_community

# %%
import os

# %%
os.environ['OPENAI_API_KEY'] = "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"
os.environ['HUGGINGFACE_API_TOKEN'] = "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"

# %%
# !pip install openai

# %%
from langchain.llms import OpenAI
llm = OpenAI(temperature=0.9)

# %%
text = "What are 5 vacation destinations for someone who likes to eat pasta?"

# %%
print(llm.predict(text))
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-40-652b389f66d4> in <cell line: 0>()
# ----> 1 print(llm.predict(text))
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     179                 warned = True
#     180                 emit_warning()
# --> 181             return wrapped(*args, **kwargs)
#     182
#     183         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/llms.py in predict(self, text, stop, **kwargs)
#    1337     ) -> str:
#    1338         _stop = None if stop is None else list(stop)
# -> 1339         return self(text, stop=_stop, **kwargs)
#    1340
#    1341     @deprecated("0.1.7", alternative="invoke", removal="1.0")
#
# ...
